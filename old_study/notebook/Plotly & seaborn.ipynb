# %%
import plotly 
plotly.tools.set_credentials_file(username='ghk829', api_key='PBkuu6oVQcjaGsMVExql')

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# Create random data with numpy
import numpy as np
df = pd.read_csv('http://www.stat.ubc.ca/~jenny/notOcto/STAT545A/examples/gapminder/data/gapminderDataFiveYear.txt', sep='\t')

# %%
df.describe()
# Out:
#              year           pop      lifeExp      gdpPercap
# count  1704.00000  1.704000e+03  1704.000000    1704.000000
# mean   1979.50000  2.960121e+07    59.474439    7215.327081
# std      17.26533  1.061579e+08    12.917107    9857.454543
# min    1952.00000  6.001100e+04    23.599000     241.165877
# 25%    1965.75000  2.793664e+06    48.198000    1202.060309
# 50%    1979.50000  7.023596e+06    60.712500    3531.846989
# 75%    1993.25000  1.958522e+07    70.845500    9325.462346
# max    2007.00000  1.318683e+09    82.603000  113523.132900

# %% [markdown]
# # Scatter Plot

# %%
# Create a trace
trace = go.Scatter(
    x = df['year'],
    y = df['pop'],
    mode = 'lines+markers',
     marker=dict(
        size='3',
        color = df['lifeExp'], #set color equal to a variable
        showscale=True
    )
)

data = [trace]

# Plot and embed in ipython notebook!
py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ghk829/31.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Box_plot & Embedding

# %%
trace0 = go.Box(
    y=df['pop']
)
trace1 = go.Box(
    y=df['lifeExp'])
data=[trace0,trace1]
py.iplot(data)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ghk829/35.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Pairs

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style="ticks", color_codes=True)
g = sns.pairplot(df)
plt.show()
